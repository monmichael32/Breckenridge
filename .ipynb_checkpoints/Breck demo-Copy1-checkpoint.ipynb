# %%
from selenium import webdriver
from datetime import datetime
import json
import requests
from bs4 import BeautifulSoup
#from selenium.webdriver.support.select import Select
#from webdriver_manager.chrome import ChromeDriverManager

# %%
options = webdriver.ChromeOptions()
options.add_argument("--ignore-certificate-errors")
options.add_argument("--incognito")
global driver
#options.add_argument("--headless")
driver = webdriver.Chrome(options=options)

# %%
driver.get("https://www.bgvgrandcentral.com/")
username = driver.find_element_by_name("loginModel.Username").send_keys("")
Password = driver.find_element_by_name("loginModel.Password").send_keys("")
form = driver.find_element_by_tag_name("form")
form.submit()
#classes.print()

# %%
driver.get("https://www.bgvgrandcentral.com/reservations/bonus-time")
driver.implicitly_wait(15)
classes = driver.find_element_by_class_name("container")
path_GC8 = '//*[@id="tabGC8"]/a'
path_GL7 = '//*[@id="tabGL7"]/a'
path_GTL = '//*[@id="tabGTL"]/a'
path_GP = '//*[@id="tabGP"]/a'
list_1 = []
list_2 = []
list_3 = []
list_4 = []

def checkin_fill(indexnumber, list_1):
  try:
    list_1[indexnumber].click()
    form = driver.find_element_by_tag_name("form")
    form.submit()
    driver.implicitly_wait(3)
    with open("page_source.html", "w") as f:
      f.write(driver.page_source)
    print("---")
  except:
    pass
  sleeps()
  table()
  #elements = driver.find_elements_by_class_name("selectable")
  #print("   Length of elements",len(elements))
  #print (elements)
  #for index in range(len(elements)):
  #print ("   Element [0]",elements[0])
  #if len(elements) > 0:
      #elements[0].find_element_by_tag_name('a').click()
      #driver.implicitly_wait(3)
      #elements = driver.find_elements_by_class_name("ui-state-active")
      #print("   Length of elements",len(elements)) #This prints as 1, There should be 2
      #form = driver.find_element_by_tag_name("form")
      #form.submit()
      #driver.implicitly_wait(3)
      #get_url = driver.current_url
      #driver.get(get_url)
      #with open("page_source.html", "w") as f:
        #f.write(driver.page_source)
      #print("---")
      #R = driver.find_element_by_id("dvResults")
      #print (R.get_attribute("innerHTML").encode("utf-8"))
#availabilityHTML = driver.execute_script("return document.body.wrapper.contentBody.contentContainer.container.dvBtCalendar.dvResults.innerHTML;")
      #availabilityHTML = driver.execute_script("return document.body.dvResults.innerHTML;")
      #print (availabilityHTML)
      #print(R.text)
      #Checkin = driver.find_element_by_name("InDate").send_keys(M,"/",D.text,"/",Y)
      #Checkout = driver.find_element_by_name("OutDate").send_keys(M,"/",CD,"/",Y)
      #form = driver.find_element_by_tag_name("form")
      #form.submit()
    
def select_lodge(lodge):
  Calendar = []
  myDate = ''
  driver.get("https://www.bgvgrandcentral.com/reservations/bonus-time")
  driver.implicitly_wait(5)
  try:
    driver.implicitly_wait(15)
    driver.find_element_by_xpath(lodge).click()
  except:
    driver.implicitly_wait(30)
    driver.find_element_by_xpath(lodge).click()
  print(lodge)
  get_dates()
  get_date_webelements()
  #print("list_1:",list_1)
  print("list_2:",list_2)
  checkinout(list_1,list_2)


def get_dates():
  #list_1 = []
  #list_2 = []
  #list_3 = []
  Calendar = driver.find_elements_by_class_name("selectable")
  Date = 0
  #print("Calendar", Calendar)

  for myDate in Calendar: 
    try:
        Calendar = driver.find_elements_by_class_name("selectable")
        #list_1 = [(driver.find_elements_by_class_name("selectable").myDate.find_elements_by_tag_name("a"))]
        #print("List_1",list_1)
        D = (myDate.find_element_by_tag_name("a"))
        Date = int(D.text)
        #list_1 = []
        #list_2 = []
        #list_1.extend([D])
        list_2.extend([Date])
        #print(list_1)
        #checkin()
        driver.implicitly_wait(3)
        #checkinout(list_1, list_2)
    except:
        pass
  return list_2

def get_date_webelements(): 
  Calendar = driver.find_elements_by_class_name("selectable")
  #print("Calendar", Calendar)
  #list_1 = []
  for myDate in Calendar:     
    #print ("myDate: ", myDate)
    try:
        Calendar = driver.find_elements_by_class_name("selectable")
        #list_1 = [(driver.find_elements_by_class_name("selectable").myDate.find_elements_by_tag_name("a"))]
        D = (myDate.find_element_by_tag_name("a"))
        list_1.extend([D])
        driver.implicitly_wait(3)
    except:
        pass
  return list_1

def get_date_webelements_deselect():
    WD = driver.find_elements_by_class_name("ui-datepicker-calendar")
    list_4 = []
    for myDate in WD:
      try:
         WD = driver.find_elements_by_class_name("ui-datepicker-calendar")
         wd = (myDate.find_element_by_tag_name("a"))
         list_4.extend([wd])
      except:
          pass
    print("list in get date:",list_4)
    return list_4
    #
    
    #

# %%
def checkinout (list_1, list_2):
  checkout = 0
  indexnumber = 0
  checkin = 0
  #print("List_2:",list_2)
  list_3 = []
  for Date in list_2:
    indexnumber = list_2.index(Date)
    checkout = Date+1
    #print("Checkout Date:",checkout)
    #checkout = list(map(itemnumber(indexnumber), islice(list_1, 1))
    if checkout in list_2 and indexnumber == 0:
      print("Running checkinout")
      print("   inlist")
      #indexnumber = list_2.index(Date)
      print("   indexnumber:",indexnumber)
      #print("   List of webelements:",list_1)
      #list_1[indexnumber].find_element_by_tag_name('a').click()
      try:
         list_1 = get_date_webelements()
         list_1[indexnumber].click()
         print("   Checkin Date:",Date)
      #list_1[checkout].find_element_by_tag_name('a').click()
         list_3 = []
         driver.implicitly_wait(3)
         list_3 = driver.find_elements_by_class_name("selectable")
         #print("List_3",list_3)
         list_3[indexnumber].click()
         print("   Checkout Date:", checkout)
         form = driver.find_element_by_tag_name("form")
         form.submit()
         with open("page_source_1.html", "w") as f:
          f.write(driver.page_source)
         print("---")
      except:
        pass
      sleeps()
      table()
    elif checkout in list_2:
      print("Running checkinout_2")
      print("   inlist")
      #indexnumber = list_2.index(Date)
      print("   indexnumber:",indexnumber)
      print("   Checkin Date:",Date)
      #print("   List of webelements:",list_1)
      #list_1[indexnumber].find_element_by_tag_name('a').click()
      try:
         list_4 = get_date_webelements_deselect()
         print("list_4:",list_4)
         list_4[0].click()
         #print("   Checkin Date:",Date)
      #list_1[checkout].find_element_by_tag_name('a').click()
         list_3 = []
         driver.implicitly_wait(3)
         list_3 = driver.find_elements_by_class_name("selectable")
         #print("List_3",list_3)
         list_3[indexnumber].click()
         print("   Checkout Date:", checkout)
         form = driver.find_element_by_tag_name("form")
         form.submit()
         with open("page_source_1.html", "w") as f:
           f.write(driver.page_source)
         sleeps()
         print("---")
      except:
        pass
      sleeps()
      table()
    else:
      print("Running checkin_fill")
      print("   Checkin Date:",Date)
      checkin_fill(indexnumber,list_1) #Can I send Date? Would this be able to access list_1, and List_2 already?

# %%
def table():
    print("Running table")
    table = driver.find_element_by_xpath('//*[@id="dvResults"]/div/table')
    cell = row.find_elements_by_tag_name("td")[1]
    print(cell.text)
def sleeps():
    print("Running sleeps")
    S = driver.find_elements_by_class_name("row well")
    for sleeps in S:
       S = driver.find_elements_by_class_name("row well")
       s = (sleeps.find_element_by_class_name("visible-lg visible-md"))
       print("Number of Sleeps:",s.text)

# %%
select_lodge(path_GC8)
#select_lodge(path_GL7)
#select_lodge(path_GTL)
#select_lodge(path_GP)
# Out:
# //*[@id="tabGC8"]/a
# list_2: [21, 22, 23, 25, 26, 27, 28, 29, 1, 2, 3, 4]
# Running checkinout
#    inlist
#    indexnumber: 0
#    Checkin Date: 21
#    Checkout Date: 22
# ---
# Running sleeps
# Running checkinout_2
#    inlist
#    indexnumber: 1
#    Checkin Date: 22
# list in get date: [<selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="9958410d-bd87-419d-bd9e-2ea6353dde1b")>, <selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="2835a3bf-eb0a-4daf-bd98-d30d2a53f945")>]
# list_4: [<selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="9958410d-bd87-419d-bd9e-2ea6353dde1b")>, <selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="2835a3bf-eb0a-4daf-bd98-d30d2a53f945")>]
# Running sleeps
# Running checkin_fill
#    Checkin Date: 23
# Running sleeps
# Running checkinout_2
#    inlist
#    indexnumber: 3
#    Checkin Date: 25
# list in get date: [<selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="9958410d-bd87-419d-bd9e-2ea6353dde1b")>, <selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="2835a3bf-eb0a-4daf-bd98-d30d2a53f945")>]
# list_4: [<selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="9958410d-bd87-419d-bd9e-2ea6353dde1b")>, <selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="2835a3bf-eb0a-4daf-bd98-d30d2a53f945")>]
# Running sleeps
# Running checkinout_2
#    inlist
#    indexnumber: 4
#    Checkin Date: 26
# list in get date: [<selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="9958410d-bd87-419d-bd9e-2ea6353dde1b")>, <selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="2835a3bf-eb0a-4daf-bd98-d30d2a53f945")>]
# list_4: [<selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="9958410d-bd87-419d-bd9e-2ea6353dde1b")>, <selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="2835a3bf-eb0a-4daf-bd98-d30d2a53f945")>]
# Running sleeps
# Running checkinout_2
#    inlist
#    indexnumber: 5
#    Checkin Date: 27
# list in get date: [<selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="9fe6919a-0451-40be-9056-904a4a787420")>, <selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="98ce758c-c927-42f4-952b-853cc0b70665")>]
# list_4: [<selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="9fe6919a-0451-40be-9056-904a4a787420")>, <selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="98ce758c-c927-42f4-952b-853cc0b70665")>]
# Running sleeps
# Running checkinout_2
#    inlist
#    indexnumber: 6
#    Checkin Date: 28
# list in get date: [<selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="35c30622-23d9-4a5e-8241-fc05c190fdab")>, <selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="a9e48756-5a42-4770-b256-d711bdee9f6e")>]
# list_4: [<selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="35c30622-23d9-4a5e-8241-fc05c190fdab")>, <selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="a9e48756-5a42-4770-b256-d711bdee9f6e")>]
# Running sleeps
# Running checkin_fill
#    Checkin Date: 29
# Running sleeps
# Running checkinout_2
#    inlist
#    indexnumber: 8
#    Checkin Date: 1
# list in get date: [<selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="a075c80f-cbd7-4898-a16d-59d527bafef0")>, <selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="472316bb-7e31-47b3-a063-0905b183ecd6")>]
# list_4: [<selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="a075c80f-cbd7-4898-a16d-59d527bafef0")>, <selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="472316bb-7e31-47b3-a063-0905b183ecd6")>]
# Running sleeps
# Running checkinout_2
#    inlist
#    indexnumber: 9
#    Checkin Date: 2
# list in get date: [<selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="6790eef8-110e-41dc-a20b-eb010c671ee9")>, <selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="cc7a6f50-eacb-483c-95b0-18f5a3e7f38f")>]
# list_4: [<selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="6790eef8-110e-41dc-a20b-eb010c671ee9")>, <selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="cc7a6f50-eacb-483c-95b0-18f5a3e7f38f")>]
# Running sleeps
# Running checkinout_2
#    inlist
#    indexnumber: 10
#    Checkin Date: 3
# list in get date: [<selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="6790eef8-110e-41dc-a20b-eb010c671ee9")>, <selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="cc7a6f50-eacb-483c-95b0-18f5a3e7f38f")>]
# list_4: [<selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="6790eef8-110e-41dc-a20b-eb010c671ee9")>, <selenium.webdriver.remote.webelement.WebElement (session="a5967315b7ee927eef7da54ce76f93a2", element="cc7a6f50-eacb-483c-95b0-18f5a3e7f38f")>]
# Running sleeps
# Running checkin_fill
#    Checkin Date: 4
# Running sleeps
